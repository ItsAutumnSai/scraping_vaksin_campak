# %%
#descriptions:
# Due to the nature of instagram being picture picture/video first, unlike facebook, x, or threads which people can share their thoughts as a written post, it's difficult to yield relevant informations on instagram.
# rows with 'replysource' being not null is an indication that the row is a reply/comment of a source post, thus at a glance their data seem to don't correlate much but they actually does,
# though the weakness is

# %%
import pandas as pd
import numpy as np

#facebook
pd.set_option('display.max_colwidth', None)
data = pd.read_csv('scraping/out/facebook_vaccine_2024_2026.classified.csv', na_values=['NaN', -1])
data = data.dropna(subset=['postdate'])
data['postdate'] = pd.to_datetime(data['postdate'])
data = data.drop_duplicates(subset=['tweet'])
data = data[(data['is_relevant'] == True) | (data["replysource"].notna())]
data = data[data['is_indonesian'] == True]
data = data.rename(columns={'retweets': 'shares'})
data = data.drop(columns=['index', 'views', 'veto_reason', 'has_topic_keyword', 'borderline', 'relevance_score', 'is_indonesian', 'is_relevant'])
# data = data[data['replysource'] == 'https://web.facebook.com/cintaofficial1212/posts/pfbid0eGCKu3qjJ9TBhE9d7NXSAZxUH5bTn1KeTcDjsgACNFYBAqyFTKzvhzyznGddGCJ4l']
# data[data.duplicated(subset=['tweet'], keep=False)]
# data = data[data['retweets'] != 0]
# data = data[data['replysource'].notna()]
print('facebook data count: ', len(data))
data_fb = data
data.head(1)
# Out:
# facebook data count:  1106
#      account                  postdate  \
# 3  Bao Chenx 2025-08-29 14:20:00+00:00
#
#                                                                                                                                                                                                                          tweet  \
# 3  Sumpah  ,udah puluhan anak yg gua bantu nanganin campak.. Dulu sebelum gua tau penyembuhan alami aja, gua kasih herbal China namanya "MAPO"  pada sembuh..Apalagi sekarang, makin gua anggap cetek lah.… Lihat selengkapnya
#
#                                                                          link  \
# 3  https://web.facebook.com/photo/?fbid=757232593738471&set=a.101256392669431
#
#    comments  shares  likes replysource
# 3       196      61    477         NaN

# %%
#instagram
data = pd.read_csv('scraping/out/instagram_vaccine_2024_2026.classified.csv', na_values=['NaN', -1])
data_old = pd.read_csv('old_result/instagram_vaccine.csv', na_values=['NaN', -1])
data = pd.concat([data, data_old], axis=0, ignore_index = True)
data = data.dropna(subset=['postdate'])
# data['reposts'] = np.nan
# data = data.rename(columns={'retweets': 'reposts'})
data = data[(data['is_relevant'] == True)]
data = data[data['is_indonesian'] == True]
data['postdate'] = pd.to_datetime(data['postdate'])
data = data.drop_duplicates(subset=['tweet'])
data = data.drop_duplicates(subset=['link'])
data = data.dropna(subset=['postdate'])
data = data.drop(columns=['index', 'retweets', 'views', 'replysource', 'veto_reason', 'has_topic_keyword', 'borderline', 'relevance_score', 'is_indonesian', 'is_relevant'])
# data = data[data['is_relevant'] == True]
# data = data[data['replysource'].notna()]
print('instagram data count: ', len(data))
data_ig = data
data.head(1)
# Out:
# instagram data count:  7
#               account                  postdate  \
# 85  klinikutamatanaya 2026-05-29 08:11:58+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     tweet  \
# 85  [BARU] Yuk vaksin di Klinik Utama Tanaya! 🏥💉💉 Ada beberapa layanan vaksinasi di Klinik Utama Tanaya Bandung lho ---------- Layanan Vaksin Influenza (Flu) Mulai dari Rp 345,000 ---------- Jenis-jenis vaksin influenza kami: - Influenza - Fluarix Tetra - Influenza - Vaxigrip Tetra - Influenza - Vaxigrip Trivalen . . Layanan Vaksin HPV Mulai dari Rp 1,395,000 -------------- Jenis-jenis Vaksin HPV kami - HPV 4 - Gardasil 4  - HPV 9 - Gardasil 9 --------------- Vaksin Campak, Rubella, Gondong: - MMR - MR - MMRV -------------- Jenis-jenis vaksin Pneumonia kami: - PCV 13 - PCV 15 - PCV 20 --------------- *Harga vaksin sudah termasuk jasa suntik dokter umum & administrasi *Tersedia layanan vaksinasi oleh dokter spesialis (harga berbeda) --------------- UNTUK RESERVASI: SILAHKAN LANGSUNG MENGHUBUNGI NOMOR WA YANG TERTERA DI PROFIL KAMI  Alamat kami: Jl. Sulanjana No. 11A Bandung #vaksininfluenza #vaksin #vaksinhpv #vaksinbandung #vaksinpneumonia
#
#                                         link  comments  likes
# 85  https://www.instagram.com/p/DY6lgzTpiKx/         0      7

# %%
#threads
data = pd.read_csv('scraping/out/threads_vaccine_2024_2026.classified.csv', na_values=['NaN', -1])
data_old = pd.read_csv('old_result/threads_vaccine.csv', na_values=['NaN', -1])
data = pd.concat([data, data_old], axis=0, ignore_index = True)
data = data.dropna(subset=['postdate'])
data = data[(data['is_relevant'] == True) | (data["replysource"].notna())]
data = data[data['is_indonesian'] == True]
data['postdate'] = pd.to_datetime(data['postdate'])
data = data.drop_duplicates(subset=['tweet'])
# data = data.drop_duplicates(subset=['link'])
data = data.dropna(subset=['postdate'])
data['tweet'] = data.apply(lambda row: row['tweet'].removeprefix(row['account']), axis=1)
data['tweet'] = data.apply(lambda row: row['tweet'].removeprefix('Verified '), axis=1)
data = data.drop(columns=['index', 'veto_reason', 'has_topic_keyword', 'borderline', 'relevance_score', 'is_indonesian', 'is_relevant'])
# data = data[data['retweets'] != 0]
# data = data[data['replysource'].notna()]
print('threads data count: ', len(data))
data_th = data
data.head(1)
# Out:
# threads data count:  8170
#      account                  postdate  \
# 0  sofiahafh 2026-01-15 11:03:25+00:00
#
#                                                                                                                                                                                           tweet  \
# 0  Habis imunisasi campak, malah kena campak. Asw Mau stop imunisasi aja rasanya kek gini  Translate 1/2 Habis imunisasi campak, malah kena campak. Asw Mau stop imunisasi aja rasanya kek gini
#
#                                                   link topic_tag  comments  \
# 0  https://www.threads.com/@sofiahafh/post/DTh2nzpkqJa       NaN       121
#
#    retweets  likes  shares replysource
# 0         1     15       6         NaN

# %%
#X
data = pd.read_csv('scraping/out/x_vaccine_2024_2026.classified.csv', na_values=['NaN', -1])
data_old = pd.read_csv('old_result/x_vaccine.csv', na_values=['NaN', -1])
data = pd.concat([data, data_old], axis=0, ignore_index = True)
data = data.dropna(subset=['postdate'])
data = data[(data['is_relevant'] == True)]
data = data[data['is_indonesian'] == True]
data['postdate'] = pd.to_datetime(data['postdate'])
data = data.drop_duplicates(subset=['tweet'])
data = data.drop_duplicates(subset=['link'])
data = data.dropna(subset=['postdate'])
data = data[data['index'] != 5]
data = data.drop(columns=['index', 'veto_reason', 'has_topic_keyword', 'borderline', 'relevance_score', 'is_indonesian', 'is_relevant'])
# data = data[data['retweets'] != 0]
# data = data[data['replysource'].notna()]
print('X data count: ', len(data))
data_x = data
data.head(1)
# Out:
# X data count:  1188
#          account                  postdate  \
# 18  syaikhkhalid 2024-06-11 23:24:02+00:00
#
#                                                                                                                                                                         tweet  \
# 18  Lalu buat apa komnas kipi dibuat kalau gak ada efek samping vaksin? kayak vaksin ini cairan dari surga saja. Berpikirlah lebih cerdas jangan bersikap khianat seperti itu
#
#                                                      link  comments  retweets  \
# 18  https://x.com/syaikhkhalid/status/1800670356224737530         0         0
#
#     likes  views replysource
# 18      8  417.0         NaN

# %%
data_fb['platform'] = 'facebook'
data_ig['platform'] = 'instagram'
data_th['platform'] = 'threads'
data_x['platform'] = 'x'
merged_data = pd.concat([data_fb, data_ig, data_th, data_x], axis=0, ignore_index=True)
merged_data
merged_data.to_csv('cleaned_data.csv', index=False)
# Out:
#                account                  postdate  \
# 0            Bao Chenx 2025-08-29 14:20:00+00:00
# 1          Neng Cintha 2026-05-13 14:48:00+00:00
# 2            Ambarwati 2026-03-27 20:22:00+00:00
# 3      Fevi Yuriandika 2026-03-09 10:24:00+00:00
# 4               Nourma 2026-03-13 02:01:00+00:00
# ...                ...                       ...
# 10466           Ajierz 2026-05-07 06:12:07+00:00
# 10467      FirzaHusain 2026-05-04 01:01:00+00:00
# 10468      FirzaHusain 2026-05-04 01:00:04+00:00
# 10469      Generali_ID 2026-06-21 03:38:00+00:00
# 10470      Generali_ID 2026-06-21 03:38:01+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         tweet  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Sumpah  ,udah puluhan anak yg gua bantu nanganin campak.. Dulu sebelum gua tau penyembuhan alami aja, gua kasih herbal China namanya "MAPO"  pada sembuh..Apalagi sekarang, makin gua anggap cetek lah.… Lihat selengkapnya
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Efek Campak Separah ini Ada yang sama kah? Bisa hilangkan ini belangnya?#fyp #campak
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Setelah covid19 terbitlah propaganda campak,sprti batuk pilek sj ini mah mdh utk disembuhkan,yaa krn agendanya,1.kembalikan otak ke RS,sbg pasien abadi.… Lihat selengkapnya
# 3      Demam gak sembuh2 dah 5 hari, baru keluar bintik2, rupa nya kena campak,, Jadi cerita nya pasien ini memang belum di vaksin campak, dah 5 hari demam gak turun2 panas nya, ortu nya mulai cemas, khawatir, dan takut anak nya kena sakit dbd dll,, Rupa nya di hari ke 5 keluar lah biang kerok nya, ruam2 merah, ciri khas campak,, Kenapa campak yang dlu jarang bisa muncul kembali dan mewabah? Karna memang herd immunity  tidak terbentuk, di karenakan banyak nya balita yang tidak di imunisasi,, sehingga memberikan ruang yang sangat besar bagi virus campak berkembang dan menyerang anak2,, maka nya jaman dlu itu di ciptakan vaksin campak agar orng2 bisa di vaksin dan terhindar dari virus campak yang mematikan itu.. Nah buat yang sudah terlanjur gak vaksin dan Buat semua bunda2 yang punya anak balita,, Tunda dlu bawa anak ke keramaian ya,, Rutin kasi vitamin D biar daya tahan tubuh nya kuat, dan gak gampang sakit,, Berikut tips2 agar terhindar dari campak :1. Rajin cuci tangan2. Jgn kontak dengan orng yg terkena campak3. Lengkapi imunisasi dasar4. Jika demam segera bawa berobat#Semuaorang#jangkauanluas#fyp
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Ternyata campak bukan hanya menyer4ng bayi tapi orang dewasa juga
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 10466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            @grok apakah hantavirus sama dengan campak ?
# 10467                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Ade Armando ga kapok2 karena merasa kebal hukum, makanya dia akan mengulangi kejahatannya terus, yuk polisi gercep, seret orang ini ke penjara
# 10468                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Orang kayak gini klu ga dijebloskan ke penjara ga bakalan kapok, selalu bikin gaduh, Ade Armando sudah jadi tersangka dari 2017, malah jadi komisaris BUMN PLN 2025  #TangkapAdeArmando
# 10469                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Campak adalah penyakit akibat infeksi virus dan dapat menyebabkan komplikasi pada berbagai organ serta menurunkan imun, sehingga tubuh menjadi lebih rentan terserang penyakit. Namun, dengan pencegahan yang tepat kamu bisa mengurangi risiko terserang virus ini.
# 10470                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          PT Asuransi Jiwa Generali Indonesia Berizin dan Diawasi oleh Otoritas Jasa Keuangan  #GeneraliIndonesia #LifetimePartner #PahamiPerlindunganmu
#
#                                                                                                                            link  \
# 0                                                    https://web.facebook.com/photo/?fbid=757232593738471&set=a.101256392669431
# 1      https://web.facebook.com/cintaofficial1212/posts/pfbid0eGCKu3qjJ9TBhE9d7NXSAZxUH5bTn1KeTcDjsgACNFYBAqyFTKzvhzyznGddGCJ4l
# 2                                                   https://web.facebook.com/photo/?fbid=1402554171900999&set=a.356653129824447
# 3      https://web.facebook.com/klinik.yuriandika/posts/pfbid0aCC9f5rm64dMuFfYWK8TSqUZdsWL6SHrr8sPpLFLzFxZqs4t4TqppqaGFHiFkT8Zl
# 4                                              https://web.facebook.com/photo/?fbid=26377372158567061&set=pcb.26377373695233574
# ...                                                                                                                         ...
# 10466                                                                           https://x.com/Ajierz/status/2052270231951970385
# 10467                                                                      https://x.com/FirzaHusain/status/2051104772569407715
# 10468                                                                      https://x.com/FirzaHusain/status/2051104540561482185
# 10469                                                                      https://x.com/Generali_ID/status/2068538900570898815
# 10470                                                                      https://x.com/Generali_ID/status/2068538905813766279
#
#        comments  shares  likes  \
# 0           196    61.0    477
# 1            23     1.0     21
# 2           461   300.0    791
# 3           892   627.0   2900
# 4             1     0.0      0
# ...         ...     ...    ...
# 10466         1     NaN      0
# 10467         4     NaN     16
# 10468       124     NaN    155
# 10469         1     NaN      6
# 10470         0     NaN      5
#
#                                                    replysource  platform  \
# 0                                                          NaN  facebook
# 1                                                          NaN  facebook
# 2                                                          NaN  facebook
# 3                                                          NaN  facebook
# 4                                                          NaN  facebook
# ...                                                        ...       ...
# 10466    https://x.com/tempurkonten/status/2052268583053640062         x
# 10467  https://x.com/HumorJonTampan/status/2051126014622011709         x
# 10468  https://x.com/HumorJonTampan/status/2051125393839825365         x
# 10469     https://x.com/Generali_ID/status/2068538805238501621         x
# 10470     https://x.com/Generali_ID/status/2068538805238501621         x
#
#       topic_tag  retweets   views
# 0           NaN       NaN     NaN
# 1           NaN       NaN     NaN
# 2           NaN       NaN     NaN
# 3           NaN       NaN     NaN
# 4           NaN       NaN     NaN
# ...         ...       ...     ...
# 10466       NaN       0.0    48.0
# 10467       NaN      12.0   517.0
# 10468       NaN     143.0  1737.0
# 10469       NaN       0.0   129.0
# 10470       NaN       0.0    76.0
#
# [10471 rows x 12 columns]
